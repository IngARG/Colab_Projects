# %% [markdown]
# <a href="https://colab.research.google.com/github/IngARG/Colab_Projects/blob/main/Folders_4-5_90_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas ultralytics pyyaml
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 879.0/879.0 kB 14.2 MB/s eta 0:00:00
# ...

# %%
import torch
torch.cpu.is_available()
# Out:
# True

# %%
# !nvidia-smi
# Out:
# Mon Nov  4 20:23:31 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   58C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# Importar la librería ultralytics
from ultralytics import YOLO
import os

# Desactivar Weights & Biases (W&B)
os.environ["WANDB_MODE"] = "disabled"
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# !yolo task=detect mode=train epochs=90 data=/content/drive/MyDrive/ITSZ/Residencia/Desarrollo/Python/k_fold_versions/v2/Project/splits/split_4/split_4_dataset.yaml model=yolov8m.pt imgsz=640 batch=8 project="Split4_run4" name="Split4_name1" verbose=True amp=False patience=10
# Out:
# ...
# 100% 49.7M/49.7M [00:00<00:00, 81.5MB/s]
# Ultralytics 8.3.27 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=train epochs=90 data=/content/drive/MyDrive/ITSZ/Residencia/Desarrollo/Python/k_fold_versions/v2/Project/splits/split_5/split_5_dataset.yaml model=yolov8m.pt imgsz=640 batch=8 project="Split5_run5" name="Split5_name1" verbose=True amp=False patience=10
# Out:
# Ultralytics 8.3.27 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
